# %% [markdown]
# # Imports

# %%
import json # to parse the json file
import pandas as pd # because arrays are oldschool (to create dataframes)
from pandas.io.json import json_normalize # for handling nested json
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from geopy.exc import GeocoderTimedOut # geopy usually ends up throwing this exception
from geopy.extra.rate_limiter import RateLimiter
from tqdm import tqdm
import time # for delay
from IPython.display import clear_output # to clear notebook output cell via code

# %% [markdown]
# # Data Preparation

# %%
with open('collegeList.json') as jsonFile: # refers to the csv we created earlier
    raw_data = json.load(jsonFile) # load data to a python var
print('Data Imported.')
# Out:
# Data Imported.

# %%
df = json_normalize(raw_data['info']) # Nested json files need to be normalised

# %% [markdown]
# ### Sub-Key 'venues' is nested inside of info, so we normalize it using json_normalize()

# %%
venues = json_normalize(data = raw_data['info'], record_path = 'venues')
venues.drop('display_area', axis = 1, inplace = True) # this column serves no purpose whatsoever

# %% [markdown]
# ### Lets check if we successfully extracted the venues data

# %%
venues.head()
# Out:
#                area               city         country
# 0        California      San Francisco   United States
# 1  Washington, D.C.  Washington, D. C.   United States
# 2          New York            Buffalo   United States
# 3           England             London  United Kingdom
# 4             Wales         Pontypridd  United Kingdom

# %% [markdown]
# ### Merging df and venues

# %%
df = pd.merge(df, venues, right_index=True, left_index=True)

# %% [markdown]
# <br><br><br><br>
#
# # Data Cleaning

# %%
df.columns # lets revise the columns we have
# Out:
# Index(['degree', 'density.fulltime', 'density.parttime', 'enhanced',
#        'fulltime_duration.unit', 'fulltime_duration.value', 'id', 'level',
#        'listing_type', 'logo', 'methods.blended', 'methods.face2face',
#        'methods.online', 'organisation', 'organisation_id',
#        'parttime_duration.unit', 'parttime_duration.value', 'summary', 'title',
#        'tuition_fee.currency', 'tuition_fee.unit', 'tuition_fee.value',
#        'venues', 'area', 'city', 'country'],
#       dtype='object')

# %%
# We seriously dont need these columns they are just clutter that we got from json we parsed
columns_to_drop = ['degree', 'density.fulltime', 'density.parttime', 
    'enhanced', 'id', 'level', 'listing_type', 'logo', 'methods.blended',
    'methods.face2face', 'methods.online','parttime_duration.unit', 
    'parttime_duration.value', 'summary', 'title', 'venues', 'fulltime_duration.value', 'fulltime_duration.unit']
df.drop(columns_to_drop, axis = 1,inplace = True)

# %%
df.isna().sum()
# Out:
# organisation             0
# organisation_id          0
# tuition_fee.currency    80
# tuition_fee.unit        80
# tuition_fee.value       80
# area                     1
# city                     0
# country                  0
# dtype: int64

# %%
df[df['tuition_fee.currency'] != 'EUR'].count()
# Out:
# organisation            80
# organisation_id         80
# tuition_fee.currency     0
# tuition_fee.unit         0
# tuition_fee.value        0
# area                    80
# city                    80
# country                 80
# dtype: int64

# %%
df = df[df['tuition_fee.currency'].notnull()] #new df from current df where tuition_fee.currency is not null 
df = df[df['area'].notnull()]

# %% [markdown]
# According to https://www.geteducated.com/career-center/detail/what-is-a-masters-degree,
# To earn a master’s degree you usually need to complete from 36 to 54 semester credits of study (or 60 to 90 quarter-credits). This equals 12 to 18 college courses.
#
# 45 is average of 36 ad 54!

# %%
df.loc[df['tuition_fee.unit'] == 'credit', 'tuition_fee.value'] = (df['tuition_fee.value']*45)/2 
# Multiplying tuition_fee.value by 45 when tuition_fee.unit is 'credit' 
# This gives us average per year fees, to get a uniform fee scale (all fees in per year format)

# %%
df.drop(['tuition_fee.currency', 'tuition_fee.unit'], axis=1, inplace=True) 
# since we have uniform values we dont need the currency and unit thus we will drrop them

# %%
# creating a column with full address and dropping the seperate columns
# df['location'] = df['area'].map(str)+', '+df['city']+', '+df['country']
# df.drop(['area', 'city', 'country'],axis=1, inplace=True)

# %%
df = df.rename(columns = {'tuition_fee.value': 'fees', 'organisation': 'college_name', 'organisation_id': 'id'})

# %%
# rearranging the columns
df = df[['id','college_name', 'fees', 'area', 'city', 'country']] # removed location from here on date 20191023

# %%
df.head()
# Out:
#       id                                       college_name     fees  \
# 0  16651           School of Nursing and Health Professions  29047.5
# 1  14338  Kogod School of Business, American University ...  35730.0
# 2  14726  University at Buffalo, The State University of...  20857.0
# 3  19026                               School of Management  21419.0
# 4    194                          University of South Wales  15514.0
#
#                area               city         country  \
# 0        California      San Francisco   United States
# 1  Washington, D.C.  Washington, D. C.   United States
# 2          New York            Buffalo   United States
# 3           England             London  United Kingdom
# 4             Wales         Pontypridd  United Kingdom
#
#                                             location
# 0           California, San Francisco, United States
# 1  Washington, D.C., Washington, D. C., United St...
# 2                   New York, Buffalo, United States
# 3                    England, London, United Kingdom
# 4                  Wales, Pontypridd, United Kingdom

# %%
def do_geocode(address):
    try:
        return geolocator.geocode(address)
    except GeocoderTimedOut:
        time.sleep(3)
        return do_geocode(address)
    
def get_latlong():
    latitude = []
    longitude = []
    collegeName = df['college_name'].to_list()
    loc = df['location'].to_list()
    
    for i in range(len(collegeName)): 
        address = collegeName[i] +', '+loc[i]
        geolocator = Nominatim(user_agent="foursquare_agent")
        geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
        new['location'] = df['name'].apply(geocode)
        location = do_geocode(address)
        try:# try with college name in address
            latitude.append(location.latitude)
            longitude.append(location.longitude)
        except AttributeError: # if location not found lat long are null 
            try: # try again without the college name in address
                address = loc[i]
                location = do_geocode(address)

                latitude.append(location.latitude)
                longitude.append(location.longitude)
            except: # if an address is not found at all simply write None to list
                latitude.append(None)
                longitude.append(None)
        clear_output() # if we dont too much space taken by output
        print('Obtained ' +str(i)+ ' latitude and logitudes.')  # Tests your patience

# %%
df['clg_city'] = df['college_name'].map(str)+' '+df['city']

# %%
tqdm.pandas()
def get_latlong():
    geolocator = Nominatim(user_agent="foursquare_agent")
    geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
    df['address'] = df['clg_city'].progress_apply(geocode)

# %%
get_latlong() # if function gets stuck, manually stop kernel and execute the block below.

# %%
import gmplot

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-a38aa0c9972b> in <module>
# ----> 1 gmap = gmplot.GoogleMapPlotter.from_geocode('School of Nursing and Health Professions, California')
#
# C:\ProgramData\Anaconda3\lib\site-packages\gmplot\gmplot.py in from_geocode(cls, location_string, zoom)
#      33     @classmethod
#      34     def from_geocode(cls, location_string, zoom=13):
# ---> 35         lat, lng = cls.geocode(location_string)
#      36         return cls(lat, lng, zoom)
#      37
#
# C:\ProgramData\Anaconda3\lib\site-packages\gmplot\gmplot.py in geocode(self, location_string)
#      41             'http://maps.googleapis.com/maps/api/geocode/json?address="%s"' % location_string)
#      42         geocode = json.loads(geocode.text)
# ---> 43         latlng_dict = geocode['results'][0]['geometry']['location']
#      44         return latlng_dict['lat'], latlng_dict['lng']
#      45
#
# IndexError: list index out of range

# %% [markdown]
# <br>

# %%
df
# Out:
#          id                                       college_name     fees  \
# 0     16651           School of Nursing and Health Professions  29047.5
# 1     14338  Kogod School of Business, American University ...  35730.0
# 2     14726  University at Buffalo, The State University of...  20857.0
# 3     19026                               School of Management  21419.0
# 4       194                          University of South Wales  15514.0
# 6       228                               Middlesex University  13338.0
# 7       434                          University of Northampton  14762.0
# 8     11437                                  Gannon University  21645.0
# 9       307                Royal Holloway University of London  21419.0
# 10    12124                            Wright State University  22860.0
# 11      520                                Teesside University   8104.0
# 12      844                           Staffordshire University  14762.0
# 13    12504                               Roosevelt University  18832.0
# 14    12039                            George Mason University  25028.0
# 15      194                          University of South Wales  15514.0
# 16    12502                                    Pace University  26505.0
# 17    19771          University of the Pacific - International  20700.0
# 18    12039                            George Mason University  25028.0
# 19      165                           University of Birmingham  25112.0
# 20    17024                                     Marist College  17257.5
# 21    12039                            George Mason University  25028.0
# 22      713                 Manchester Metropolitan University  17946.0
# 23    12039                            George Mason University  25028.0
# 24      150    University of the West of England (UWE Bristol)  15051.0
# 25    12168                      University of Texas Arlington  18984.0
# 26    17024                                     Marist College  17257.5
# 27      228                               Middlesex University  16093.0
# 28    13777                           Wichita State University  13905.0
# 29      284                                Coventry University  18293.0
# 31      194                          University of South Wales  15514.0
# ...     ...                                                ...      ...
# 2107    265                                 University of York   9031.0
# 2109    110                              University of Glasgow  24337.0
# 2110  14244                                 Hofstra University  27922.5
# 2111    215                           University of St Andrews  25460.0
# 2112    592                        Nottingham Trent University  16788.0
# 2113  11725     Georgia Institute of Technology (Georgia Tech)  31072.5
# 2114  13145                  University of Missouri - Columbia  24459.0
# 2116    110                              University of Glasgow  24337.0
# 2117  12324                                 Queen's University  39066.0
# 2118    232                            University of Sheffield  26166.0
# 2119  11701                      South Dakota State University  13140.0
# 2120    300                         City, University of London  18293.0
# 2121    530                          University of West London  15746.0
# 2122  17055                   University of Houston Clear Lake  18606.0
# 2123  11993                              Iowa State University  23793.0
# 2125    119                          University of East London  15352.0
# 2126  10703                          Charles Darwin University  12827.0
# 2127  11316                               Edge Hill University  15051.0
# 2128    530                          University of West London  15051.0
# 2129    275                               University of Sussex  19393.0
# 2130    247                        Edinburgh Napier University   8023.0
# 2131  18041                      California Miramar University  20599.0
# 2132  17131                        Prairie View A&M University  15727.0
# 2133  12543                 University of Massachusetts Lowell  23809.0
# 2134    272                             Heriot-Watt University  21627.0
# 2135  11023                   Florida International University  20362.5
# 2136  11497                           University of Cincinnati   5774.0
# 2137  11405                         San Diego State University   8075.0
# 2138   1878                                             Rdi Uk   6638.0
# 2139  12100                  Rochester Institute of Technology  41100.0
#
#                               area                 city         country  \
# 0                       California        San Francisco   United States
# 1                 Washington, D.C.    Washington, D. C.   United States
# 2                         New York              Buffalo   United States
# 3                          England               London  United Kingdom
# 4                            Wales           Pontypridd  United Kingdom
# 6                          England               London  United Kingdom
# 7                          England          Northampton  United Kingdom
# 8                     Pennsylvania                 Erie   United States
# 9                          England               London  United Kingdom
# 10                            Ohio               Dayton   United States
# 11                         England        Middlesbrough  United Kingdom
# 12                         England       Stoke-on-Trent  United Kingdom
# 13                        Illinois              Chicago   United States
# 14                        Virginia              Fairfax   United States
# 15                           Wales           Pontypridd  United Kingdom
# 16                        New York        New York City   United States
# 17                      California             Stockton   United States
# 18                        Virginia              Fairfax   United States
# 19                         England           Birmingham  United Kingdom
# 20                        New York         Poughkeepsie   United States
# 21                        Virginia              Fairfax   United States
# 22                         England           Manchester  United Kingdom
# 23                        Virginia              Fairfax   United States
# 24                         England              Bristol  United Kingdom
# 25                           Texas           Texas City   United States
# 26                        New York         Poughkeepsie   United States
# 27                         England               London  United Kingdom
# 28                          Kansas              Wichita   United States
# 29                         England             Coventry  United Kingdom
# 31                           Wales           Pontypridd  United Kingdom
# ...                            ...                  ...             ...
# 2107                       Florida                Tampa   United States
# 2109                      New York             Syracuse   United States
# 2110                      New York        New York City   United States
# 2111                      Illinois             Evanston   United States
# 2112                       England  Newcastle upon Tyne  United Kingdom
# 2113                      Virginia             Richmond   United States
# 2114  Australian Capital Territory             Canberra       Australia
# 2116                       Florida   Jacksonville Beach   United States
# 2117                       Ontario             Hamilton          Canada
# 2118                      Missouri          Saint Louis   United States
# 2119                North Carolina        Winston-Salem   United States
# 2120                     Wisconsin               Somers   United States
# 2121                       England  Newcastle upon Tyne  United Kingdom
# 2122                       England           Birmingham  United Kingdom
# 2123                      Illinois                Lisle   United States
# 2125                    New Mexico           Las Cruces   United States
# 2126                        Nevada             Paradise   United States
# 2127                         Texas              Webster   United States
# 2128                      Michigan     Dearborn Heights   United States
# 2129                       England                Luton  United Kingdom
# 2130                       England               London  United Kingdom
# 2131                       England               London  United Kingdom
# 2132                       England               London  United Kingdom
# 2133                   Connecticut            Fairfield   United States
# 2134                      Virginia             Richmond   United States
# 2135                       England              Reading  United Kingdom
# 2136                       Ontario               Guelph          Canada
# 2137                 Massachusetts               Boston   United States
# 2138                      Oklahoma           Stillwater   United States
# 2139                          Ohio            Cleveland   United States
#
#                                                location  \
# 0              California, San Francisco, United States
# 1     Washington, D.C., Washington, D. C., United St...
# 2                      New York, Buffalo, United States
# 3                       England, London, United Kingdom
# 4                     Wales, Pontypridd, United Kingdom
# 6                       England, London, United Kingdom
# 7                  England, Northampton, United Kingdom
# 8                     Pennsylvania, Erie, United States
# 9                       England, London, United Kingdom
# 10                          Ohio, Dayton, United States
# 11               England, Middlesbrough, United Kingdom
# 12              England, Stoke-on-Trent, United Kingdom
# 13                     Illinois, Chicago, United States
# 14                     Virginia, Fairfax, United States
# 15                    Wales, Pontypridd, United Kingdom
# 16               New York, New York City, United States
# 17                  California, Stockton, United States
# 18                     Virginia, Fairfax, United States
# 19                  England, Birmingham, United Kingdom
# 20                New York, Poughkeepsie, United States
# 21                     Virginia, Fairfax, United States
# 22                  England, Manchester, United Kingdom
# 23                     Virginia, Fairfax, United States
# 24                     England, Bristol, United Kingdom
# 25                     Texas, Texas City, United States
# 26                New York, Poughkeepsie, United States
# 27                      England, London, United Kingdom
# 28                       Kansas, Wichita, United States
# 29                    England, Coventry, United Kingdom
# 31                    Wales, Pontypridd, United Kingdom
# ...                                                 ...
# 2107                      Florida, Tampa, United States
# 2109                  New York, Syracuse, United States
# 2110             New York, New York City, United States
# 2111                  Illinois, Evanston, United States
# 2112       England, Newcastle upon Tyne, United Kingdom
# 2113                  Virginia, Richmond, United States
# 2114  Australian Capital Territory, Canberra, Australia
# 2116         Florida, Jacksonville Beach, United States
# 2117                          Ontario, Hamilton, Canada
# 2118               Missouri, Saint Louis, United States
# 2119       North Carolina, Winston-Salem, United States
# 2120                   Wisconsin, Somers, United States
# 2121       England, Newcastle upon Tyne, United Kingdom
# 2122                England, Birmingham, United Kingdom
# 2123                     Illinois, Lisle, United States
# 2125              New Mexico, Las Cruces, United States
# 2126                    Nevada, Paradise, United States
# 2127                      Texas, Webster, United States
# 2128          Michigan, Dearborn Heights, United States
# 2129                     England, Luton, United Kingdom
# 2130                    England, London, United Kingdom
# 2131                    England, London, United Kingdom
# 2132                    England, London, United Kingdom
# 2133              Connecticut, Fairfield, United States
# 2134                  Virginia, Richmond, United States
# 2135                   England, Reading, United Kingdom
# 2136                            Ontario, Guelph, Canada
# 2137               Massachusetts, Boston, United States
# 2138                Oklahoma, Stillwater, United States
# 2139                     Ohio, Cleveland, United States
#
#                                                clg_city  \
# 0     School of Nursing and Health Professions San F...
# 1     Kogod School of Business, American University ...
# 2     University at Buffalo, The State University of...
# 3                           School of Management London
# 4                  University of South Wales Pontypridd
# 6                           Middlesex University London
# 7                 University of Northampton Northampton
# 8                                Gannon University Erie
# 9            Royal Holloway University of London London
# 10                       Wright State University Dayton
# 11                    Teesside University Middlesbrough
# 12              Staffordshire University Stoke-on-Trent
# 13                         Roosevelt University Chicago
# 14                      George Mason University Fairfax
# 15                 University of South Wales Pontypridd
# 16                        Pace University New York City
# 17    University of the Pacific - International Stoc...
# 18                      George Mason University Fairfax
# 19                  University of Birmingham Birmingham
# 20                          Marist College Poughkeepsie
# 21                      George Mason University Fairfax
# 22        Manchester Metropolitan University Manchester
# 23                      George Mason University Fairfax
# 24    University of the West of England (UWE Bristol...
# 25             University of Texas Arlington Texas City
# 26                          Marist College Poughkeepsie
# 27                          Middlesex University London
# 28                     Wichita State University Wichita
# 29                         Coventry University Coventry
# 31                 University of South Wales Pontypridd
# ...                                                 ...
# 2107                           University of York Tampa
# 2109                     University of Glasgow Syracuse
# 2110                   Hofstra University New York City
# 2111                  University of St Andrews Evanston
# 2112    Nottingham Trent University Newcastle upon Tyne
# 2113  Georgia Institute of Technology (Georgia Tech)...
# 2114         University of Missouri - Columbia Canberra
# 2116           University of Glasgow Jacksonville Beach
# 2117                        Queen's University Hamilton
# 2118                University of Sheffield Saint Louis
# 2119        South Dakota State University Winston-Salem
# 2120                  City, University of London Somers
# 2121      University of West London Newcastle upon Tyne
# 2122        University of Houston Clear Lake Birmingham
# 2123                        Iowa State University Lisle
# 2125               University of East London Las Cruces
# 2126                 Charles Darwin University Paradise
# 2127                       Edge Hill University Webster
# 2128         University of West London Dearborn Heights
# 2129                         University of Sussex Luton
# 2130                 Edinburgh Napier University London
# 2131               California Miramar University London
# 2132                 Prairie View A&M University London
# 2133       University of Massachusetts Lowell Fairfield
# 2134                    Heriot-Watt University Richmond
# 2135           Florida International University Reading
# 2136                    University of Cincinnati Guelph
# 2137                  San Diego State University Boston
# 2138                                  Rdi Uk Stillwater
# 2139        Rochester Institute of Technology Cleveland
#
#                                                 address
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4     (Bike Shed, Central Avenue, Pontypridd, Hawtho...
# 6     (Middlesex University, Greyhound Hill, Hendon,...
# 7     (The Pavillion, Boughton Green Road, Hill Top,...
# 8     (Gannon University, West 7th Street, Erie, Eri...
# 9     (Royal Holloway, Founder's Steam Tunnel, Riple...
# 10                                                 None
# 11    (Teesside University, Southfield Road, Southfi...
# 12    (Staffordshire University, Leek Road, Joiner's...
# 13    (Roosevelt University, 430, South Michigan Ave...
# 14    (George Mason University, Sandy Creek Way, Cou...
# 15    (Bike Shed, Central Avenue, Pontypridd, Hawtho...
# 16    (Pace University, Frankfort Street, Financial ...
# 17                                                 None
# 18    (George Mason University, Sandy Creek Way, Cou...
# 19    (University of Birmingham Edgbaston Campus, Ri...
# 20    (Marist College, Marist 4, Town of Poughkeepsi...
# 21    (George Mason University, Sandy Creek Way, Cou...
# 22    (Manchester Metropolitan University, Chester S...
# 23    (George Mason University, Sandy Creek Way, Cou...
# 24    (University of the West of England, Frenchay C...
# 25                                                 None
# 26    (Marist College, Marist 4, Town of Poughkeepsi...
# 27    (Middlesex University, Greyhound Hill, Hendon,...
# 28    (Wichita State University, Perimeter Road, Wic...
# 29    (Coventry University, Cox Street, Bishopsgate ...
# 31    (Bike Shed, Central Avenue, Pontypridd, Hawtho...
# ...                                                 ...
# 2107                                               None
# 2109                                               None
# 2110  (Hofstra University, East Pedestrian Bridge, E...
# 2111                                               None
# 2112                                               None
# 2113                                               None
# 2114                                               None
# 2116                                               None
# 2117                                               None
# 2118                                               None
# 2119                                               None
# 2120                                               None
# 2121                                               None
# 2122                                               None
# 2123                                               None
# 2125                                               None
# 2126  (Universidad Metropolitana, Avenida 10 de Agos...
# 2127                                               None
# 2128                                               None
# 2129                                               None
# 2130                                               None
# 2131  (San Diego Miramar College, Miramar College Dr...
# 2132                                               None
# 2133                                               None
# 2134                                               None
# 2135                                               None
# 2136                                               None
# 2137                                               None
# 2138                                               None
# 2139                                               None
#
# [2059 rows x 9 columns]

# %%
# execute this block if get_latlong() gets stuck
with open('latFile.txt','a+') as latFile:
    latFile.write(str(latitude)+',')
with open('longFile.txt','a+') as longFile:
    longFile.write(str(longitude)+',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-ba5a460226cd> in <module>
#       1 # execute this block if get_latlong() gets stuck
#       2 with open('latFile.txt','a+') as latFile:
# ----> 3     latFile.write(str(latitude)+',')
#       4 with open('longFile.txt','a+') as longFile:
#       5     longFile.write(str(longitude)+',')
#
# NameError: name 'latitude' is not defined

# %% [markdown]
# <br>
#
# ## Making new columns in df from latFile and longFile.
#
# <br>

# %%
with open('latFile.txt') as latFile:
    latitude = latFile.read()
with open('longFile.txt') as longFile:
    longitude = longFile.read()
latitude= latitude.strip('][').split(', ') #converting latitude from string to float
longitude= longitude.strip('][').split(', ') #converting latitude from string to float

# %%
for i in range(len(latitude)):
    try:
        latitude[i] = float(latitude[i])
    except ValueError:
        latitude[i] = None
for i in range(len(longitude)):
    try:
        longitude[i] = float(longitude[i])
    except ValueError:
        longitude[i] = None

# %%
df = df[df['area'].notnull()]

# %%
df.head()

# %%
df.to_csv('college_dataset.csv')

# %% [markdown]
# <br>
#
# ## We have saved the data to college_dataset.csv
#
# <br>

# %%
df = pd.read_csv("college_dataset.csv")

# %%
df = df[df['latitude'].notnull()] #new df from current df where tuition_fee.currency is not null
df = df[df['longitude'].notnull()]

# %%
df.head()

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.head()

# %%
df.shape

# %% [markdown]
# <br><br><br><br><br>
#
#
# # Exploratory Data Analysis

# %% [markdown]
# So now that we have our data it's time to explore it. Lets see the number per country. The venues data frame would make it easy to do so.

# %%
df.head()

# %%
df['country'].value_counts()

# %% [markdown]
# ## So, I have no clue but somehow all these countries crept in through our json, We don't need them since they are too less in numbers, we'll keep only US, UK and Canada

# %%
df = df[df['country'].str.contains("United States|United Kingdom|Canada")] 
# keeping only the locations with location-country as US, UK, Canada

# %%
df.shape

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()

# %%
import folium

# %%
df_usa = df[df['country'] == 'United States']
df_usa.shape

# %%
usa_coordinates = [37.0902, -95.7129]
USAmap = folium.Map(location=usa_coordinates, zoom_start = 4)

college_markers = folium.map.FeatureGroup()

for lat, lng, label in zip(df_usa.latitude, df_usa.longitude, df_usa.college_name):
    college_markers.add_child(
        folium.features.Marker(
            location=[lat, lng],
            tooltip=label,
        )
    )

# add incidents to map
USAmap.add_child(college_markers)

# %%
usa_map.choropleth(
    geo_data=world_geo,
    data=df_can,
    columns=['Country', 'Total'],
    key_on='feature.properties.name',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Immigration to Canada'
)

# display map
world_map
