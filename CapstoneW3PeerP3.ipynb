# %% [markdown]
# # Capstone Week 3 Peer Graded Assignment Part 3

# %% [markdown]
# #### Import Libraries

# %%
import numpy as np # library to handle data in a vectorized manner
import re
import pandas as pd # library for data analsysis
import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# These libs Might need installation:
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')

# %% [markdown]
# #### If URL loading fails please manually Download and update file path [create var or put it in read_csv()] and import FinalDf.csv

# %%
# finalDfURL = 'https://github.com/xtreme0021/Capstone/blob/master/CSVs/FinalDf.csv'
# finaldf = pd.read_csv(finalDfURL)
finaldf = pd.read_csv('FinalDf.csv')
print('Dataset Loaded')
# Out:
# Dataset Loaded

# %%
finaldf.head()
# Out:
#   PostalCode           Borough                     Neighborhood   Latitude  \
# 0        M3A        North York                        Parkwoods  43.753259
# 1        M4A        North York                 Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Harbourfront,Regent Park  43.654260
# 3        M6A        North York  Lawrence Heights,Lawrence Manor  43.718518
# 4        M7A      Queen's Park                     Queen's Park  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %% [markdown]
# ## Basic EDA

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(finaldf['Borough'].unique()),
        finaldf.shape[0]
    )
)
# Out:
# The dataframe has 11 boroughs and 103 neighborhoods.
# False    103
# Name: Borough, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-d64ea7020964> in <module>
# ----> 1 toronto_df = re.findall("Toronto",  finaldf['Borough'])
#       2 toronto_df.value_counts()
#
# ~/conda/envs/python/lib/python3.6/re.py in findall(pattern, string, flags)
#     220
#     221     Empty matches are included in the result."""
# --> 222     return _compile(pattern, flags).findall(string)
#     223
#     224 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
map_toronto = folium.Map(location=[43.6532, -79.3832], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(finaldf['Latitude'], finaldf['Longitude'], finaldf['Borough'], finaldf['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.5,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Folium Client_id and version

# %%
CLIENT_ID = 'D4WODCWUGACTLS12LBW0G5DGQQXJEJQXBDBBBWP3OIYUOSIM' # your Foursquare ID
CLIENT_SECRET = 'IF2ULMXSQ4ZFKEZOM1TG3WAROEVRVSXQGSTXA2H5BRJCQJHM' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
